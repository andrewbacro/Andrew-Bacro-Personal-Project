# %%
import os
import pandas as pd
new_path = "\\Users\\bacro\\OneDrive\\Desktop\\PierrepontDS_2\\Datasets"
os.chdir(new_path)
college = pd.read_csv('IPEDS_data.csv', encoding = "Latin-1")
college.head(5)
# Out:
#    ID number                                 Name  year    ZIP code  \
# 0     100654             Alabama A & M University  2013       35762
# 1     100663  University of Alabama at Birmingham  2013  35294-0110
# 2     100690                   Amridge University  2013  36117-3553
# 3     100706  University of Alabama in Huntsville  2013       35899
# 4     100724             Alabama State University  2013  36104-0271
#
#                               Highest degree offered        County name  \
# 0             Doctor's degree - research/scholarship     Madison County
# 1  Doctor's degree - research/scholarship and pro...   Jefferson County
# 2  Doctor's degree - research/scholarship and pro...  Montgomery County
# 3  Doctor's degree - research/scholarship and pro...     Madison County
# 4  Doctor's degree - research/scholarship and pro...  Montgomery County
#
#    Longitude location of institution  Latitude location of institution  \
# ...

# %%
college_name = college["Name"]

# %%
reading_25 = college["SAT Critical Reading 25th percentile score"]
reading_75 = college["SAT Critical Reading 75th percentile score"]
math_25 = college["SAT Math 25th percentile score"]
math_75 = college["SAT Math 75th percentile score"]
sat_score_list = []
tuple_score_list = []
for i in range(len(reading_25)):
    sum = ((reading_25.get(i) + reading_75.get(i)) / 2) + ((math_25.get(i) + math_75.get(i)) / 2)
    sat_score_list.append(sum)
    tuple_score_list.append((sum, college_name[i]))

# %%
tuple_score_list
# Out:
# [(810.0, 'Alabama A & M University'),
#  (1165.0, 'University of Alabama at Birmingham'),
#  (nan, 'Amridge University'),
#  (1155.0, 'University of Alabama in Huntsville'),
#  (855.0, 'Alabama State University'),
#  (1125.0, 'The University of Alabama'),
#  (nan, 'Athens State University'),
#  (nan, 'Auburn University at Montgomery'),
#  (1165.0, 'Auburn University'),
#  (1155.0, 'Birmingham Southern College'),
#  (nan, 'Concordia College Alabama'),
#  (nan, 'Faulkner University'),
#  (940.0, 'Huntingdon College'),
#  (965.0, 'Jacksonville State University'),
#  (1145.0, 'Judson College'),
#  (nan, 'University of West Alabama'),
#  (nan, 'Miles College'),
#  (1115.0, 'University of Mobile'),
#  (1061.5, 'University of Montevallo'),
#  (970.5, 'University of North Alabama'),
#  (916.5, 'Oakwood University'),
#  (1125.0, 'Samford University'),
#  (995.0, 'University of South Alabama'),
#  (1080.0, 'Spring Hill College'),
#  (810.5, 'Stillman College'),
#  (nan, 'Talladega College'),
# ...

# %%
mean_sat = {}                       #This contains a dictionary of scores with the name being the key and mean sat score being the value (DNU)
college_sat = []                    #This contains the scores (DNU)
list = []                           #This contains a list of tuples with the element 0 of the tuple being the name of the college and element 1 being the mean sat score
counter = 0
for i in range(len(college_name)):
    reading = (college.loc[counter][26] + college.loc[counter][27]) / 2
    math = (college.loc[counter][28] + college.loc[counter][29]) / 2
    mean_sat[college_name[i]] = reading + math
    counter += 1
for name in mean_sat:
    tuple = (name, mean_sat[name])
    list.append(tuple)
    college_sat.append(mean_sat[name])

# %%
percent_admitted = college["Percent admitted - total"]

# %%
from matplotlib import pyplot as plt
plt.scatter(college_sat, percent_admitted[:1517])
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.relplot(x=sat_score_list, y=percent_admitted, hue=percent_admitted)
plt.xlabel("Mean SAT score")
plt.show()
#As we can see, the higher the score, the lower the acceptance rate.

# %%
from matplotlib import pyplot as plt
import numpy as np
 
# Creating histogram
fig, ax = plt.subplots(figsize =(10, 7))
#ax.hist(college_sat, bins = [0, 200, 400, 600, 800, 1000, 1200, 1400, 1600])
 
ax.hist(college_sat, bins = [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600])

# Show plot
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
 
# Creating histogram
fig, ax = plt.subplots(figsize =(10, 7))
#ax.hist(college_sat, bins = [0, 200, 400, 600, 800, 1000, 1200, 1400, 1600])
 
ax.hist(college_sat, bins = [0, 50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950, 1000, 1050, 1100, 1150,
 1200, 1250, 1300, 1350, 1400, 1450, 1500, 1550, 1600])
xlist = [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600]
plt.xticks(xlist)
plt.ylabel("FREQUENCY OF SCORE")
plt.xlabel("SCHOOL MEDIAN SAT SCORE")
# Show plot
plt.show()

# %%
print(sat_score_list)
# Out:
# [810.0, 1165.0, nan, 1155.0, 855.0, 1125.0, nan, nan, 1165.0, 1155.0, nan, nan, 940.0, 965.0, 1145.0, nan, nan, 1115.0, 1061.5, 970.5, 916.5, 1125.0, 995.0, 1080.0, 810.5, nan, nan, 915.0, nan, nan, nan, 1000.0, nan, 1145.0, 1106.5, 1160.0, 1050.0, nan, 1070.0, 1037.5, 865.0, nan, 1110.0, 1125.0, 800.5, 965.5, 895.0, nan, nan, 1080.0, 1120.0, 1039.0, 1200.0, 1142.5, 1015.0, 985.0, nan, 850.0, 975.0, 970.0, 1095.0, 1121.5, nan, 980.0, 1545.0, 1106.5, 1240.0, nan, 905.0, 920.0, 895.0, 1070.0, 1015.0, 850.0, 925.0, 1025.0, 910.0, 1020.0, 880.0, 920.0, 950.0, 1355.0, 1195.0, 1130.0, 1300.0, 1090.0, 1280.0, 1215.0, 1095.0, 1075.0, 1210.0, 1006.5, 995.0, nan, 1410.0, nan, 1060.0, nan, 990.0, nan, 1480.0, 910.0, 1015.0, nan, nan, nan, 1030.0, nan, 925.0, 1095.0, 1190.0, 989.5, 1145.0, nan, 935.0, nan, 985.0, 1305.0, 959.5, 1020.0, 1175.0, 1235.0, nan, 1150.0, 1460.0, 1130.0, 1090.0, 1215.0, 995.0, 1170.0, 1030.0, 1290.0, 1366.5, 1030.0, 1110.0, 1005.0, 950.0, 1380.0, 1250.0, 1185.0, 1040.0,
# ...

# %%
#ONLY RUN THIS ONCE
top_10 = []
for i in range(10):
    top_10.append(max(sat_score_list))
    sat_score_list.remove(max(sat_score_list))

# %%
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
figure(figsize=(16, 12), dpi=80)
name_list = ["CAL Tech", "Chicago", "Harvard", "Princeton", "Yale", 
"MIT", "Northwestern", "Wash U", "Harvey Mudd", "Columbia"]
plt.bar(name_list, top_10)
plt.title('Top 10 Colleges (SAT score)')
plt.xlabel('xAxis name')
plt.ylabel('yAxis name')
plt.show()
